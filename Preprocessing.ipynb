# %%
import utils.Preprocessings as prep
reload(prep)
import utils.general as ge

import os

# %%
inputDir = '/home/mountain/Desktop/BrainNets/data/Brats17TrainingData'

# %%
prep.preProcessingWithN4(inputDir = inputDir,
                         modals = ['t1ce', 't1', 't2', 'flair'], 
                         parallel = True)
# Out:
# 170923-20:15:48,142 interface INFO:
# 	 stdout 2017-09-23T20:15:48.142677:
# 170923-20:15:48,143 interface INFO:
# 	 stdout 2017-09-23T20:15:48.143809:
# 170923-20:15:48,142 interface INFO:
# 	 stdout 2017-09-23T20:15:48.142677:
# 170923-20:15:48,155 interface INFO:
# 	 stdout 2017-09-23T20:15:48.143809:Running N4 for 3-dimensional images.
# 170923-20:15:48,160 interface INFO:
# 	 stdout 2017-09-23T20:15:48.142677:Running N4 for 3-dimensional images.
# 170923-20:15:48,166 interface INFO:
# 	 stdout 2017-09-23T20:15:48.143809:
# 170923-20:15:48,164 interface INFO:
# 	 stdout 2017-09-23T20:15:48.164713:
# 170923-20:15:48,156 interface INFO:
# 	 stdout 2017-09-23T20:15:48.142677:Running N4 for 3-dimensional images.
# 170923-20:15:48,170 interface INFO:
# 	 stdout 2017-09-23T20:15:48.142677:
# 170923-20:15:48,172 interface INFO:
# 	 stdout 2017-09-23T20:15:48.142677:
# 170923-20:15:48,170 interface INFO:
# 	 stdout 2017-09-23T20:15:48.143809:Mask not read.  Creating Otsu mask.
# ...
